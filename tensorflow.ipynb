# %% [markdown]
# <a href="https://colab.research.google.com/github/Poornachandra-dh/practise_tensorflow/blob/main/tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================
# MNIST Digit Classification with Plots
# =========================================

import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

#  Load Dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

#  Normalize (0–255 → 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0

#  Build Model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

#  Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

#  Train Model
history = model.fit(
    x_train, y_train,
    epochs=5,
    batch_size=32,
    validation_split=0.1
)

#  Plot Accuracy
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#  Plot Loss
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

#  Evaluate on Test Data
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("\nTest Accuracy:", test_accuracy)

#  Make Predictions
predictions = model.predict(x_test)

#  Show Sample Prediction
plt.figure()
plt.imshow(x_test[0], cmap='gray')
plt.title(f"Predicted: {np.argmax(predictions[0])}, Actual: {y_test[0]}")
plt.axis('off')
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8733 - loss: 0.4395 - val_accuracy: 0.9635 - val_loss: 0.1226
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9677 - loss: 0.1087 - val_accuracy: 0.9712 - val_loss: 0.1002
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9765 - loss: 0.0730 - val_accuracy: 0.9770 - val_loss: 0.0781
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9840 - loss: 0.0509 - val_accuracy: 0.9768 - val_loss: 0.0821
# Epoch 5/5
# ...

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

#  Create Dataset
x_train = np.array([1, 2, 3, 4, 5], dtype=float).reshape(-1,1)
y_train = np.array([2, 4, 6, 8, 10], dtype=float)

x_test = np.array([11,12,13,14], dtype=float).reshape(-1,1)

#  Build Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(16, activation='relu', input_shape=[1]),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1)
])

#  Compile
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    loss='mse'
)

#  Train
model.fit(x_train, y_train, epochs=500, verbose=0)

#  Predict
predictions = model.predict(x_test)

for i, val in enumerate(x_test):
    print(f"Input: {val[0]}  → Predicted: {predictions[i][0]:.2f}")

#  Plot
plt.scatter(x_train, y_train, label="Training Data")
plt.scatter(x_test, predictions, color='red', label="Predictions")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Input: 11.0  → Predicted: 22.02
# Input: 12.0  → Predicted: 24.02
# Input: 13.0  → Predicted: 26.02
# Input: 14.0  → Predicted: 28.03

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# Load MNIST
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

# Build CNN (better than dense for images)
model = tf.keras.Sequential([
    tf.keras.layers.Reshape((28,28,1), input_shape=(28,28)),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(x_train, y_train, epochs=5, validation_split=0.1)


# Take two random test digits
img1 = x_test[0]
img2 = x_test[1]

# Predict
pred1 = np.argmax(model.predict(img1.reshape(1,28,28)))
pred2 = np.argmax(model.predict(img2.reshape(1,28,28)))

print("Digit 1:", pred1)
print("Digit 2:", pred2)

result_add = pred1 + pred2
result_sub = pred1 - pred2

print("Addition:", result_add)
print("Subtraction:", result_sub)


plt.subplot(1,2,1)
plt.imshow(img1, cmap='gray')
plt.title(f"Predicted: {pred1}")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(img2, cmap='gray')
plt.title(f"Predicted: {pred2}")
plt.axis('off')

plt.show()

print(f"{pred1} + {pred2} = {result_add}")
print(f"{pred1} - {pred2} = {result_sub}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8945 - loss: 0.3370 - val_accuracy: 0.9850 - val_loss: 0.0508
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9839 - loss: 0.0529 - val_accuracy: 0.9877 - val_loss: 0.0413
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9901 - loss: 0.0309 - val_accuracy: 0.9880 - val_loss: 0.0359
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9919 - loss: 0.0231 - val_accuracy: 0.9880 - val_loss: 0.0414
# Epoch 5/5
# ...

# %%
# 1️⃣ Clone your repository
# !git clone https://github.com/Poornachandra-dh/practise_tensorflow.git

# 2️⃣ Go inside repo folder
# %cd practise_tensorflow
# Out:
# fatal: destination path 'practise_tensorflow' already exists and is not an empty directory.
# /content/practise_tensorflow/practise_tensorflow

# %%
# %cd /content
# Out:
# /content

# %%
# !rm -rf practise_tensorflow

# %%
# !git clone https://github.com/Poornachandra-dh/practise_tensorflow.git
# %cd practise_tensorflow
# Out:
# Cloning into 'practise_tensorflow'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/practise_tensorflow

# %%
# !ls /content
# Out:
# practise_tensorflow  sample_data

# %%
# !pwd
# Out:
# /content/practise_tensorflow

# %%
# !ls
# Out:
# README.md
